# %% [markdown]
# #### Ensemble - RandomForest & ExtraTree
#  - 배깅 방식의 앙상블 ==> 중복 허용한 랜덤 샐픔 + 동일 모델(DecisionTree)
#    * 대표 알고리즘 : RandomForestC/R
#  - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델(DecisionTree)
#    * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# - 와인분류 => 0과 1 2개 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
#  모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
wineDF = pd.read_csv(r'C:\Users\KDP-17\EX_PANDAS6\MachineLearning\data\wine.csv')
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
# 타겟/라벨의 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()

featureDF = wineDF[wineDF.columns[:-1]]
targetSR =  wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}, targetSr : {targetSR.shape}')
# Out:
# featureDF : (6497, 3), targetSr : (6497,)

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(featureDF,targetSR,
                                                    test_size=0.2,
                                                    stratify=targetSR,
                                                    random_state=10)

# %%
print(f'X_train : {X_train.shape}, y_train : {y_train.shape}')
print(f'X_test : {X_test.shape}, y_test : {y_test.shape}')
# Out:
# X_train : (5197, 3), y_train : (5197,)
# X_test : (1300, 3), y_test : (1300,)

# %% [markdown]
# [3] 학습 진행

# %%
# 학습 방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 배깅 - RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# 인스턴스 객체 생성 => 100개의 내부 DT 모델에서 사용할 데이터셋 생성
#                    random state 매개변수 설정으로 고정된 데이터셋 생성
#                    oob_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용
rf_model = RandomForestClassifier(random_state=7,
                                  oob_score=True)

# 학습
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=7)

# %%
# 모델 파라미터
print(f'classes_ : {rf_model.classes_}')
print(f'n_classes_ : {rf_model.n_classes_}개')
print(f'feature_names_in_ : {rf_model.feature_names_in_}')
print(f'n_features_in_ : {rf_model.n_features_in_}개')
print(f'feature_importances_ : {rf_model.feature_importances_}')
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2개
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in_ : 3개
# feature_importances_ : [0.23396134 0.49681321 0.26922545]

# %%
# 모델 파라미터 
print(f'       : {rf_model.estimator_}')
for est in rf_model.estimators_: print(est)
# Out:
#        : DecisionTreeClassifier()
# DecisionTreeClassifier(max_features='sqrt', random_state=327741615)
# DecisionTreeClassifier(max_features='sqrt', random_state=976413892)
# DecisionTreeClassifier(max_features='sqrt', random_state=1202242073)
# DecisionTreeClassifier(max_features='sqrt', random_state=1369975286)
# DecisionTreeClassifier(max_features='sqrt', random_state=1882953283)
# DecisionTreeClassifier(max_features='sqrt', random_state=2053951699)
# DecisionTreeClassifier(max_features='sqrt', random_state=959775639)
# DecisionTreeClassifier(max_features='sqrt', random_state=1956722279)
# DecisionTreeClassifier(max_features='sqrt', random_state=2052949340)
# DecisionTreeClassifier(max_features='sqrt', random_state=1322904761)
# DecisionTreeClassifier(max_features='sqrt', random_state=165338510)
# DecisionTreeClassifier(max_features='sqrt', random_state=1133316631)
# DecisionTreeClassifier(max_features='sqrt', random_state=4812360)
# DecisionTreeClassifier(max_features='sqrt', random_state=372560217)
# DecisionTreeClassifier(max_features='sqrt', random_state=309457262)
# DecisionTreeClassifier(max_features='sqrt', random_state=1801189930)
# DecisionTreeClassifier(max_features='sqrt', random_state=1152936666)
# DecisionTreeClassifier(max_features='sqrt', random_state=68334472)
# DecisionTreeClassifier(max_features='sqrt', random_state=2146978983)
# DecisionTreeClassifier(max_features='sqrt', random_state=119248870)
# DecisionTreeClassifier(max_features='sqrt', random_state=769786948)
# DecisionTreeClassifier(max_features='sqrt', random_state=1583990192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1304549247)
# DecisionTreeClassifier(max_features='sqrt', random_state=1420943751)
# DecisionTreeClassifier(max_features='sqrt', random_state=1636129708)
# DecisionTreeClassifier(max_features='sqrt', random_state=1687674368)
# DecisionTreeClassifier(max_features='sqrt', random_state=283194443)
# DecisionTreeClassifier(max_features='sqrt', random_state=748743479)
# DecisionTreeClassifier(max_features='sqrt', random_state=1237575930)
# DecisionTreeClassifier(max_features='sqrt', random_state=740097030)
# DecisionTreeClassifier(max_features='sqrt', random_state=1759190803)
# DecisionTreeClassifier(max_features='sqrt', random_state=833359292)
# DecisionTreeClassifier(max_features='sqrt', random_state=916483116)
# DecisionTreeClassifier(max_features='sqrt', random_state=1485942463)
# DecisionTreeClassifier(max_features='sqrt', random_state=1941857605)
# DecisionTreeClassifier(max_features='sqrt', random_state=1844809528)
# DecisionTreeClassifier(max_features='sqrt', random_state=1852015768)
# DecisionTreeClassifier(max_features='sqrt', random_state=1127788727)
# DecisionTreeClassifier(max_features='sqrt', random_state=106941365)
# DecisionTreeClassifier(max_features='sqrt', random_state=1077017712)
# DecisionTreeClassifier(max_features='sqrt', random_state=431854331)
# DecisionTreeClassifier(max_features='sqrt', random_state=1094761661)
# DecisionTreeClassifier(max_features='sqrt', random_state=1933291456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1508798754)
# DecisionTreeClassifier(max_features='sqrt', random_state=989143352)
# DecisionTreeClassifier(max_features='sqrt', random_state=747550921)
# DecisionTreeClassifier(max_features='sqrt', random_state=208262606)
# DecisionTreeClassifier(max_features='sqrt', random_state=1248819750)
# DecisionTreeClassifier(max_features='sqrt', random_state=1757192964)
# DecisionTreeClassifier(max_features='sqrt', random_state=1879603694)
# DecisionTreeClassifier(max_features='sqrt', random_state=571958409)
# DecisionTreeClassifier(max_features='sqrt', random_state=1927692119)
# DecisionTreeClassifier(max_features='sqrt', random_state=100556259)
# DecisionTreeClassifier(max_features='sqrt', random_state=1652057283)
# DecisionTreeClassifier(max_features='sqrt', random_state=1075502152)
# DecisionTreeClassifier(max_features='sqrt', random_state=1535344467)
# DecisionTreeClassifier(max_features='sqrt', random_state=725906352)
# DecisionTreeClassifier(max_features='sqrt', random_state=830456065)
# DecisionTreeClassifier(max_features='sqrt', random_state=2008983232)
# DecisionTreeClassifier(max_features='sqrt', random_state=431532432)
# DecisionTreeClassifier(max_features='sqrt', random_state=879820150)
# DecisionTreeClassifier(max_features='sqrt', random_state=2072909727)
# DecisionTreeClassifier(max_features='sqrt', random_state=2107823453)
# DecisionTreeClassifier(max_features='sqrt', random_state=488352684)
# DecisionTreeClassifier(max_features='sqrt', random_state=1599380060)
# DecisionTreeClassifier(max_features='sqrt', random_state=1938096892)
# DecisionTreeClassifier(max_features='sqrt', random_state=2050422343)
# DecisionTreeClassifier(max_features='sqrt', random_state=1497897239)
# DecisionTreeClassifier(max_features='sqrt', random_state=1571487242)
# DecisionTreeClassifier(max_features='sqrt', random_state=1187621609)
# DecisionTreeClassifier(max_features='sqrt', random_state=1451346723)
# DecisionTreeClassifier(max_features='sqrt', random_state=1917728192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1153832253)
# DecisionTreeClassifier(max_features='sqrt', random_state=1966724487)
# DecisionTreeClassifier(max_features='sqrt', random_state=1348596887)
# DecisionTreeClassifier(max_features='sqrt', random_state=771276892)
# DecisionTreeClassifier(max_features='sqrt', random_state=311923447)
# DecisionTreeClassifier(max_features='sqrt', random_state=612959456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1185621653)
# DecisionTreeClassifier(max_features='sqrt', random_state=358664548)
# DecisionTreeClassifier(max_features='sqrt', random_state=1944945571)
# DecisionTreeClassifier(max_features='sqrt', random_state=202873313)
# DecisionTreeClassifier(max_features='sqrt', random_state=1516030531)
# DecisionTreeClassifier(max_features='sqrt', random_state=1332338555)
# DecisionTreeClassifier(max_features='sqrt', random_state=676025563)
# DecisionTreeClassifier(max_features='sqrt', random_state=1214271969)
# DecisionTreeClassifier(max_features='sqrt', random_state=1590645779)
# DecisionTreeClassifier(max_features='sqrt', random_state=1808153499)
# DecisionTreeClassifier(max_features='sqrt', random_state=1971789316)
# DecisionTreeClassifier(max_features='sqrt', random_state=1861190419)
# DecisionTreeClassifier(max_features='sqrt', random_state=941989921)
# DecisionTreeClassifier(max_features='sqrt', random_state=1798548603)
# DecisionTreeClassifier(max_features='sqrt', random_state=1773786398)
# DecisionTreeClassifier(max_features='sqrt', random_state=2088312505)
# DecisionTreeClassifier(max_features='sqrt', random_state=1745574629)
# DecisionTreeClassifier(max_features='sqrt', random_state=1260873545)
# DecisionTreeClassifier(max_features='sqrt', random_state=775033821)
# DecisionTreeClassifier(max_features='sqrt', random_state=1474484177)
# DecisionTreeClassifier(max_features='sqrt', random_state=1035597695)
# DecisionTreeClassifier(max_features='sqrt', random_state=1289946527)

# %%
print(f'oob_score : {rf_model.oob_score_}')
# Out:
# oob_score : 0.8974408312487974

# %% [markdown]
# [4] 성능 평가

# %%
train_score = rf_model.score(X_train,y_train)
test_score = rf_model.score(X_test,y_test)

# %%
print(f'train_score : {train_score}, test_score : {test_score}')
# Out:
# train_score : 0.9976909755628247, test_score : 0.8930769230769231

# %% [markdown]
# [5] 튜닝
#  - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#    * 범위가 넓은 하이퍼파라미터 설정에 좋음
#    * 지정된 범윙에서 지정된 횟수만큼 하이퍼파라미터를 추출하여 조합 진행

# %%
# 모듈로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼파라미터 설정
params = {'max_depth':range(2,16),
          'min_samples_leaf':range(5,16)}

# %%
rf_model = RandomForestClassifier(random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model,param_distributions=params,
                              n_iter=50,
                              verbose=4)

# %%
searchCV.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END ..max_depth=9, min_samples_leaf=13;, score=0.875 total time=   0.2s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=13;, score=0.864 total time=   0.2s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=13;, score=0.868 total time=   0.2s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=13;, score=0.863 total time=   0.2s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=13;, score=0.868 total time=   0.2s
# [CV 1/5] END ..max_depth=8, min_samples_leaf=12;, score=0.877 total time=   0.1s
# [CV 2/5] END ..max_depth=8, min_samples_leaf=12;, score=0.865 total time=   0.2s
# [CV 3/5] END ..max_depth=8, min_samples_leaf=12;, score=0.868 total time=   0.2s
# [CV 4/5] END ..max_depth=8, min_samples_leaf=12;, score=0.861 total time=   0.1s
# [CV 5/5] END ..max_depth=8, min_samples_leaf=12;, score=0.871 total time=   0.2s
# [CV 1/5] END ..max_depth=12, min_samples_leaf=9;, score=0.879 total time=   0.2s
# [CV 2/5] END ..max_depth=12, min_samples_leaf=9;, score=0.873 total time=   0.2s
# [CV 3/5] END ..max_depth=12, min_samples_leaf=9;, score=0.871 total time=   0.2s
# [CV 4/5] END ..max_depth=12, min_samples_leaf=9;, score=0.863 total time=   0.2s
# [CV 5/5] END ..max_depth=12, min_samples_leaf=9;, score=0.881 total time=   0.2s
# [CV 1/5] END ..max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.1s
# [CV 2/5] END ..max_depth=2, min_samples_leaf=11;, score=0.756 total time=   0.1s
# [CV 3/5] END ..max_depth=2, min_samples_leaf=11;, score=0.755 total time=   0.0s
# [CV 4/5] END ..max_depth=2, min_samples_leaf=11;, score=0.771 total time=   0.1s
# [CV 5/5] END ..max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.1s
# [CV 1/5] END .max_depth=12, min_samples_leaf=12;, score=0.870 total time=   0.2s
# [CV 2/5] END .max_depth=12, min_samples_leaf=12;, score=0.865 total time=   0.2s
# [CV 3/5] END .max_depth=12, min_samples_leaf=12;, score=0.875 total time=   0.2s
# [CV 4/5] END .max_depth=12, min_samples_leaf=12;, score=0.859 total time=   0.2s
# [CV 5/5] END .max_depth=12, min_samples_leaf=12;, score=0.875 total time=   0.2s
# [CV 1/5] END ...max_depth=5, min_samples_leaf=6;, score=0.870 total time=   0.1s
# [CV 2/5] END ...max_depth=5, min_samples_leaf=6;, score=0.852 total time=   0.1s
# [CV 3/5] END ...max_depth=5, min_samples_leaf=6;, score=0.862 total time=   0.1s
# [CV 4/5] END ...max_depth=5, min_samples_leaf=6;, score=0.859 total time=   0.1s
# [CV 5/5] END ...max_depth=5, min_samples_leaf=6;, score=0.859 total time=   0.1s
# [CV 1/5] END .max_depth=15, min_samples_leaf=13;, score=0.869 total time=   0.2s
# [CV 2/5] END .max_depth=15, min_samples_leaf=13;, score=0.865 total time=   0.2s
# [CV 3/5] END .max_depth=15, min_samples_leaf=13;, score=0.870 total time=   0.2s
# [CV 4/5] END .max_depth=15, min_samples_leaf=13;, score=0.862 total time=   0.2s
# [CV 5/5] END .max_depth=15, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 1/5] END .max_depth=15, min_samples_leaf=12;, score=0.876 total time=   0.2s
# [CV 2/5] END .max_depth=15, min_samples_leaf=12;, score=0.863 total time=   0.2s
# [CV 3/5] END .max_depth=15, min_samples_leaf=12;, score=0.872 total time=   0.2s
# [CV 4/5] END .max_depth=15, min_samples_leaf=12;, score=0.860 total time=   0.2s
# [CV 5/5] END .max_depth=15, min_samples_leaf=12;, score=0.873 total time=   0.2s
# [CV 1/5] END ..max_depth=14, min_samples_leaf=6;, score=0.881 total time=   0.2s
# [CV 2/5] END ..max_depth=14, min_samples_leaf=6;, score=0.878 total time=   0.2s
# [CV 3/5] END ..max_depth=14, min_samples_leaf=6;, score=0.876 total time=   0.2s
# [CV 4/5] END ..max_depth=14, min_samples_leaf=6;, score=0.870 total time=   0.2s
# [CV 5/5] END ..max_depth=14, min_samples_leaf=6;, score=0.885 total time=   0.2s
# [CV 1/5] END ..max_depth=4, min_samples_leaf=11;, score=0.859 total time=   0.1s
# [CV 2/5] END ..max_depth=4, min_samples_leaf=11;, score=0.838 total time=   0.1s
# [CV 3/5] END ..max_depth=4, min_samples_leaf=11;, score=0.846 total time=   0.1s
# [CV 4/5] END ..max_depth=4, min_samples_leaf=11;, score=0.841 total time=   0.1s
# [CV 5/5] END ..max_depth=4, min_samples_leaf=11;, score=0.843 total time=   0.1s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=15;, score=0.831 total time=   0.1s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=15;, score=0.821 total time=   0.1s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=15;, score=0.802 total time=   0.1s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=15;, score=0.825 total time=   0.1s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=15;, score=0.830 total time=   0.1s
# [CV 1/5] END .max_depth=11, min_samples_leaf=12;, score=0.873 total time=   0.2s
# [CV 2/5] END .max_depth=11, min_samples_leaf=12;, score=0.863 total time=   0.2s
# [CV 3/5] END .max_depth=11, min_samples_leaf=12;, score=0.870 total time=   0.2s
# [CV 4/5] END .max_depth=11, min_samples_leaf=12;, score=0.859 total time=   0.2s
# [CV 5/5] END .max_depth=11, min_samples_leaf=12;, score=0.869 total time=   0.2s
# [CV 1/5] END ..max_depth=11, min_samples_leaf=5;, score=0.879 total time=   0.2s
# [CV 2/5] END ..max_depth=11, min_samples_leaf=5;, score=0.877 total time=   0.2s
# [CV 3/5] END ..max_depth=11, min_samples_leaf=5;, score=0.885 total time=   0.2s
# [CV 4/5] END ..max_depth=11, min_samples_leaf=5;, score=0.870 total time=   0.2s
# [CV 5/5] END ..max_depth=11, min_samples_leaf=5;, score=0.879 total time=   0.2s
# [CV 1/5] END ..max_depth=8, min_samples_leaf=11;, score=0.875 total time=   0.2s
# [CV 2/5] END ..max_depth=8, min_samples_leaf=11;, score=0.864 total time=   0.2s
# [CV 3/5] END ..max_depth=8, min_samples_leaf=11;, score=0.869 total time=   0.2s
# [CV 4/5] END ..max_depth=8, min_samples_leaf=11;, score=0.859 total time=   0.2s
# [CV 5/5] END ..max_depth=8, min_samples_leaf=11;, score=0.872 total time=   0.2s
# [CV 1/5] END .max_depth=14, min_samples_leaf=14;, score=0.874 total time=   0.2s
# [CV 2/5] END .max_depth=14, min_samples_leaf=14;, score=0.865 total time=   0.2s
# [CV 3/5] END .max_depth=14, min_samples_leaf=14;, score=0.871 total time=   0.2s
# [CV 4/5] END .max_depth=14, min_samples_leaf=14;, score=0.859 total time=   0.2s
# [CV 5/5] END .max_depth=14, min_samples_leaf=14;, score=0.871 total time=   0.2s
# [CV 1/5] END ...max_depth=6, min_samples_leaf=9;, score=0.869 total time=   0.1s
# [CV 2/5] END ...max_depth=6, min_samples_leaf=9;, score=0.862 total time=   0.1s
# [CV 3/5] END ...max_depth=6, min_samples_leaf=9;, score=0.863 total time=   0.1s
# [CV 4/5] END ...max_depth=6, min_samples_leaf=9;, score=0.858 total time=   0.1s
# [CV 5/5] END ...max_depth=6, min_samples_leaf=9;, score=0.864 total time=   0.1s
# [CV 1/5] END ...max_depth=3, min_samples_leaf=5;, score=0.828 total time=   0.1s
# [CV 2/5] END ...max_depth=3, min_samples_leaf=5;, score=0.812 total time=   0.1s
# [CV 3/5] END ...max_depth=3, min_samples_leaf=5;, score=0.802 total time=   0.1s
# [CV 4/5] END ...max_depth=3, min_samples_leaf=5;, score=0.824 total time=   0.1s
# [CV 5/5] END ...max_depth=3, min_samples_leaf=5;, score=0.833 total time=   0.1s
# [CV 1/5] END ...max_depth=6, min_samples_leaf=5;, score=0.875 total time=   0.1s
# [CV 2/5] END ...max_depth=6, min_samples_leaf=5;, score=0.857 total time=   0.1s
# [CV 3/5] END ...max_depth=6, min_samples_leaf=5;, score=0.865 total time=   0.1s
# [CV 4/5] END ...max_depth=6, min_samples_leaf=5;, score=0.857 total time=   0.2s
# [CV 5/5] END ...max_depth=6, min_samples_leaf=5;, score=0.864 total time=   0.1s
# [CV 1/5] END ..max_depth=10, min_samples_leaf=7;, score=0.877 total time=   0.2s
# [CV 2/5] END ..max_depth=10, min_samples_leaf=7;, score=0.870 total time=   0.2s
# [CV 3/5] END ..max_depth=10, min_samples_leaf=7;, score=0.882 total time=   0.2s
# [CV 4/5] END ..max_depth=10, min_samples_leaf=7;, score=0.871 total time=   0.2s
# [CV 5/5] END ..max_depth=10, min_samples_leaf=7;, score=0.879 total time=   0.2s
# [CV 1/5] END .max_depth=11, min_samples_leaf=14;, score=0.872 total time=   0.2s
# [CV 2/5] END .max_depth=11, min_samples_leaf=14;, score=0.859 total time=   0.2s
# [CV 3/5] END .max_depth=11, min_samples_leaf=14;, score=0.867 total time=   0.2s
# [CV 4/5] END .max_depth=11, min_samples_leaf=14;, score=0.861 total time=   0.2s
# [CV 5/5] END .max_depth=11, min_samples_leaf=14;, score=0.869 total time=   0.2s
# [CV 1/5] END ..max_depth=8, min_samples_leaf=13;, score=0.875 total time=   0.2s
# [CV 2/5] END ..max_depth=8, min_samples_leaf=13;, score=0.866 total time=   0.2s
# [CV 3/5] END ..max_depth=8, min_samples_leaf=13;, score=0.868 total time=   0.2s
# [CV 4/5] END ..max_depth=8, min_samples_leaf=13;, score=0.854 total time=   0.2s
# [CV 5/5] END ..max_depth=8, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 1/5] END .max_depth=13, min_samples_leaf=15;, score=0.871 total time=   0.2s
# [CV 2/5] END .max_depth=13, min_samples_leaf=15;, score=0.861 total time=   0.2s
# [CV 3/5] END .max_depth=13, min_samples_leaf=15;, score=0.865 total time=   0.2s
# [CV 4/5] END .max_depth=13, min_samples_leaf=15;, score=0.866 total time=   0.2s
# [CV 5/5] END .max_depth=13, min_samples_leaf=15;, score=0.871 total time=   0.2s
# [CV 1/5] END ...max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 2/5] END ...max_depth=2, min_samples_leaf=8;, score=0.756 total time=   0.1s
# [CV 3/5] END ...max_depth=2, min_samples_leaf=8;, score=0.755 total time=   0.1s
# [CV 4/5] END ...max_depth=2, min_samples_leaf=8;, score=0.771 total time=   0.0s
# [CV 5/5] END ...max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 1/5] END .max_depth=13, min_samples_leaf=10;, score=0.878 total time=   0.2s
# [CV 2/5] END .max_depth=13, min_samples_leaf=10;, score=0.863 total time=   0.2s
# [CV 3/5] END .max_depth=13, min_samples_leaf=10;, score=0.875 total time=   0.2s
# [CV 4/5] END .max_depth=13, min_samples_leaf=10;, score=0.865 total time=   0.2s
# [CV 5/5] END .max_depth=13, min_samples_leaf=10;, score=0.876 total time=   0.2s
# [CV 1/5] END ..max_depth=12, min_samples_leaf=5;, score=0.883 total time=   0.2s
# [CV 2/5] END ..max_depth=12, min_samples_leaf=5;, score=0.876 total time=   0.2s
# [CV 3/5] END ..max_depth=12, min_samples_leaf=5;, score=0.879 total time=   0.2s
# [CV 4/5] END ..max_depth=12, min_samples_leaf=5;, score=0.870 total time=   0.3s
# [CV 5/5] END ..max_depth=12, min_samples_leaf=5;, score=0.886 total time=   0.2s
# [CV 1/5] END ...max_depth=6, min_samples_leaf=6;, score=0.874 total time=   0.1s
# [CV 2/5] END ...max_depth=6, min_samples_leaf=6;, score=0.858 total time=   0.2s
# [CV 3/5] END ...max_depth=6, min_samples_leaf=6;, score=0.863 total time=   0.1s
# [CV 4/5] END ...max_depth=6, min_samples_leaf=6;, score=0.856 total time=   0.1s
# [CV 5/5] END ...max_depth=6, min_samples_leaf=6;, score=0.868 total time=   0.1s
# [CV 1/5] END .max_depth=14, min_samples_leaf=12;, score=0.875 total time=   0.2s
# [CV 2/5] END .max_depth=14, min_samples_leaf=12;, score=0.865 total time=   0.2s
# [CV 3/5] END .max_depth=14, min_samples_leaf=12;, score=0.870 total time=   0.3s
# [CV 4/5] END .max_depth=14, min_samples_leaf=12;, score=0.859 total time=   0.2s
# [CV 5/5] END .max_depth=14, min_samples_leaf=12;, score=0.872 total time=   0.2s
# [CV 1/5] END ...max_depth=5, min_samples_leaf=7;, score=0.871 total time=   0.1s
# [CV 2/5] END ...max_depth=5, min_samples_leaf=7;, score=0.856 total time=   0.1s
# [CV 3/5] END ...max_depth=5, min_samples_leaf=7;, score=0.864 total time=   0.1s
# [CV 4/5] END ...max_depth=5, min_samples_leaf=7;, score=0.859 total time=   0.1s
# [CV 5/5] END ...max_depth=5, min_samples_leaf=7;, score=0.859 total time=   0.1s
# [CV 1/5] END ..max_depth=14, min_samples_leaf=8;, score=0.879 total time=   0.2s
# [CV 2/5] END ..max_depth=14, min_samples_leaf=8;, score=0.875 total time=   0.2s
# [CV 3/5] END ..max_depth=14, min_samples_leaf=8;, score=0.878 total time=   0.2s
# [CV 4/5] END ..max_depth=14, min_samples_leaf=8;, score=0.862 total time=   0.2s
# [CV 5/5] END ..max_depth=14, min_samples_leaf=8;, score=0.882 total time=   0.2s
# [CV 1/5] END ..max_depth=15, min_samples_leaf=6;, score=0.885 total time=   0.3s
# [CV 2/5] END ..max_depth=15, min_samples_leaf=6;, score=0.879 total time=   0.2s
# [CV 3/5] END ..max_depth=15, min_samples_leaf=6;, score=0.876 total time=   0.3s
# [CV 4/5] END ..max_depth=15, min_samples_leaf=6;, score=0.873 total time=   0.5s
# [CV 5/5] END ..max_depth=15, min_samples_leaf=6;, score=0.883 total time=   0.9s
# [CV 1/5] END ..max_depth=2, min_samples_leaf=14;, score=0.754 total time=   0.4s
# [CV 2/5] END ..max_depth=2, min_samples_leaf=14;, score=0.756 total time=   0.3s
# [CV 3/5] END ..max_depth=2, min_samples_leaf=14;, score=0.755 total time=   0.4s
# [CV 4/5] END ..max_depth=2, min_samples_leaf=14;, score=0.771 total time=   0.4s
# [CV 5/5] END ..max_depth=2, min_samples_leaf=14;, score=0.754 total time=   0.4s
# [CV 1/5] END ..max_depth=11, min_samples_leaf=8;, score=0.878 total time=   0.8s
# [CV 2/5] END ..max_depth=11, min_samples_leaf=8;, score=0.870 total time=   0.8s
# [CV 3/5] END ..max_depth=11, min_samples_leaf=8;, score=0.873 total time=   0.8s
# [CV 4/5] END ..max_depth=11, min_samples_leaf=8;, score=0.869 total time=   0.8s
# [CV 5/5] END ..max_depth=11, min_samples_leaf=8;, score=0.879 total time=   0.8s
# [CV 1/5] END .max_depth=15, min_samples_leaf=15;, score=0.876 total time=   0.7s
# [CV 2/5] END .max_depth=15, min_samples_leaf=15;, score=0.862 total time=   0.7s
# [CV 3/5] END .max_depth=15, min_samples_leaf=15;, score=0.863 total time=   0.7s
# [CV 4/5] END .max_depth=15, min_samples_leaf=15;, score=0.866 total time=   0.7s
# [CV 5/5] END .max_depth=15, min_samples_leaf=15;, score=0.873 total time=   0.7s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=10;, score=0.829 total time=   0.4s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=10;, score=0.815 total time=   0.4s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=10;, score=0.802 total time=   0.4s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=10;, score=0.823 total time=   0.4s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=10;, score=0.830 total time=   0.4s
# [CV 1/5] END ..max_depth=15, min_samples_leaf=8;, score=0.880 total time=   0.8s
# [CV 2/5] END ..max_depth=15, min_samples_leaf=8;, score=0.875 total time=   0.8s
# [CV 3/5] END ..max_depth=15, min_samples_leaf=8;, score=0.872 total time=   0.8s
# [CV 4/5] END ..max_depth=15, min_samples_leaf=8;, score=0.863 total time=   0.8s
# [CV 5/5] END ..max_depth=15, min_samples_leaf=8;, score=0.876 total time=   0.8s
# [CV 1/5] END ...max_depth=4, min_samples_leaf=8;, score=0.858 total time=   0.5s
# [CV 2/5] END ...max_depth=4, min_samples_leaf=8;, score=0.837 total time=   0.5s
# [CV 3/5] END ...max_depth=4, min_samples_leaf=8;, score=0.846 total time=   0.5s
# [CV 4/5] END ...max_depth=4, min_samples_leaf=8;, score=0.842 total time=   0.5s
# [CV 5/5] END ...max_depth=4, min_samples_leaf=8;, score=0.839 total time=   0.5s
# [CV 1/5] END ..max_depth=6, min_samples_leaf=10;, score=0.881 total time=   0.6s
# [CV 2/5] END ..max_depth=6, min_samples_leaf=10;, score=0.860 total time=   0.6s
# [CV 3/5] END ..max_depth=6, min_samples_leaf=10;, score=0.865 total time=   0.6s
# [CV 4/5] END ..max_depth=6, min_samples_leaf=10;, score=0.859 total time=   0.6s
# [CV 5/5] END ..max_depth=6, min_samples_leaf=10;, score=0.869 total time=   0.6s
# [CV 1/5] END .max_depth=10, min_samples_leaf=11;, score=0.872 total time=   0.8s
# [CV 2/5] END .max_depth=10, min_samples_leaf=11;, score=0.865 total time=   0.8s
# [CV 3/5] END .max_depth=10, min_samples_leaf=11;, score=0.874 total time=   0.7s
# [CV 4/5] END .max_depth=10, min_samples_leaf=11;, score=0.858 total time=   0.8s
# [CV 5/5] END .max_depth=10, min_samples_leaf=11;, score=0.871 total time=   0.8s
# [CV 1/5] END ..max_depth=4, min_samples_leaf=14;, score=0.859 total time=   0.5s
# [CV 2/5] END ..max_depth=4, min_samples_leaf=14;, score=0.841 total time=   0.5s
# [CV 3/5] END ..max_depth=4, min_samples_leaf=14;, score=0.844 total time=   0.5s
# [CV 4/5] END ..max_depth=4, min_samples_leaf=14;, score=0.843 total time=   0.5s
# [CV 5/5] END ..max_depth=4, min_samples_leaf=14;, score=0.844 total time=   0.5s
# [CV 1/5] END .max_depth=13, min_samples_leaf=12;, score=0.875 total time=   0.8s
# [CV 2/5] END .max_depth=13, min_samples_leaf=12;, score=0.865 total time=   0.4s
# [CV 3/5] END .max_depth=13, min_samples_leaf=12;, score=0.870 total time=   0.2s
# [CV 4/5] END .max_depth=13, min_samples_leaf=12;, score=0.861 total time=   0.2s
# [CV 5/5] END .max_depth=13, min_samples_leaf=12;, score=0.872 total time=   0.2s
# [CV 1/5] END ...max_depth=9, min_samples_leaf=8;, score=0.878 total time=   0.2s
# [CV 2/5] END ...max_depth=9, min_samples_leaf=8;, score=0.868 total time=   0.2s
# [CV 3/5] END ...max_depth=9, min_samples_leaf=8;, score=0.872 total time=   0.2s
# [CV 4/5] END ...max_depth=9, min_samples_leaf=8;, score=0.862 total time=   0.2s
# [CV 5/5] END ...max_depth=9, min_samples_leaf=8;, score=0.874 total time=   0.2s
# [CV 1/5] END .max_depth=12, min_samples_leaf=10;, score=0.876 total time=   0.2s
# [CV 2/5] END .max_depth=12, min_samples_leaf=10;, score=0.868 total time=   0.2s
# [CV 3/5] END .max_depth=12, min_samples_leaf=10;, score=0.868 total time=   0.2s
# [CV 4/5] END .max_depth=12, min_samples_leaf=10;, score=0.862 total time=   0.2s
# [CV 5/5] END .max_depth=12, min_samples_leaf=10;, score=0.877 total time=   0.2s
# [CV 1/5] END .max_depth=14, min_samples_leaf=11;, score=0.873 total time=   0.2s
# [CV 2/5] END .max_depth=14, min_samples_leaf=11;, score=0.864 total time=   0.2s
# [CV 3/5] END .max_depth=14, min_samples_leaf=11;, score=0.873 total time=   0.2s
# [CV 4/5] END .max_depth=14, min_samples_leaf=11;, score=0.860 total time=   0.2s
# [CV 5/5] END .max_depth=14, min_samples_leaf=11;, score=0.874 total time=   0.3s
# [CV 1/5] END ...max_depth=3, min_samples_leaf=8;, score=0.828 total time=   0.1s
# [CV 2/5] END ...max_depth=3, min_samples_leaf=8;, score=0.815 total time=   0.1s
# [CV 3/5] END ...max_depth=3, min_samples_leaf=8;, score=0.805 total time=   0.1s
# [CV 4/5] END ...max_depth=3, min_samples_leaf=8;, score=0.823 total time=   0.1s
# [CV 5/5] END ...max_depth=3, min_samples_leaf=8;, score=0.831 total time=   0.1s
# [CV 1/5] END ..max_depth=13, min_samples_leaf=7;, score=0.879 total time=   0.2s
# [CV 2/5] END ..max_depth=13, min_samples_leaf=7;, score=0.874 total time=   0.2s
# [CV 3/5] END ..max_depth=13, min_samples_leaf=7;, score=0.881 total time=   0.2s
# [CV 4/5] END ..max_depth=13, min_samples_leaf=7;, score=0.865 total time=   0.2s
# [CV 5/5] END ..max_depth=13, min_samples_leaf=7;, score=0.884 total time=   0.2s
# [CV 1/5] END ...max_depth=3, min_samples_leaf=6;, score=0.828 total time=   0.1s
# [CV 2/5] END ...max_depth=3, min_samples_leaf=6;, score=0.816 total time=   0.1s
# [CV 3/5] END ...max_depth=3, min_samples_leaf=6;, score=0.802 total time=   0.1s
# [CV 4/5] END ...max_depth=3, min_samples_leaf=6;, score=0.824 total time=   0.1s
# [CV 5/5] END ...max_depth=3, min_samples_leaf=6;, score=0.831 total time=   0.1s
# [CV 1/5] END ..max_depth=15, min_samples_leaf=7;, score=0.878 total time=   0.2s
# [CV 2/5] END ..max_depth=15, min_samples_leaf=7;, score=0.879 total time=   0.3s
# [CV 3/5] END ..max_depth=15, min_samples_leaf=7;, score=0.880 total time=   0.2s
# [CV 4/5] END ..max_depth=15, min_samples_leaf=7;, score=0.868 total time=   0.2s
# [CV 5/5] END ..max_depth=15, min_samples_leaf=7;, score=0.884 total time=   0.2s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=11;, score=0.833 total time=   0.1s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=11;, score=0.815 total time=   0.1s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=11;, score=0.802 total time=   0.1s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=11;, score=0.824 total time=   0.1s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=11;, score=0.830 total time=   0.1s
# [CV 1/5] END ..max_depth=14, min_samples_leaf=7;, score=0.877 total time=   0.2s
# [CV 2/5] END ..max_depth=14, min_samples_leaf=7;, score=0.877 total time=   0.2s
# [CV 3/5] END ..max_depth=14, min_samples_leaf=7;, score=0.876 total time=   0.2s
# [CV 4/5] END ..max_depth=14, min_samples_leaf=7;, score=0.868 total time=   0.3s
# [CV 5/5] END ..max_depth=14, min_samples_leaf=7;, score=0.882 total time=   0.2s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=13;, score=0.875 total time=   0.2s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=13;, score=0.861 total time=   0.2s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=13;, score=0.866 total time=   0.2s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=13;, score=0.857 total time=   0.2s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=13;, score=0.859 total time=   0.2s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=7), n_iter=50,
#                    param_distributions={'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'searchCV.best_score : {searchCV.best_score_}')
print(f'searchCV.best_params_ : {searchCV.best_params_}')
print(f'searchCV.best_estimator_ : {searchCV.best_estimator_}')

cv_resulDF = pd.DataFrame(searchCV.cv_results_)

cv_resulDF
# Out:
# searchCV.best_score : 0.8789675723698822
# searchCV.best_params_ : {'min_samples_leaf': 6, 'max_depth': 15}
# searchCV.best_estimator_ : RandomForestClassifier(max_depth=15, min_samples_leaf=6, random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.262262      0.021541         0.015130        0.001089
# 1        0.237405      0.003348         0.012916        0.002982
# 2        0.278785      0.010487         0.015950        0.002238
# 3        0.142632      0.004944         0.010467        0.005551
# 4        0.249642      0.004628         0.017169        0.002763
# 5        0.206455      0.011654         0.016031        0.006802
# 6        0.256978      0.004203         0.015723        0.002892
# 7        0.263313      0.014797         0.016604        0.003824
# 8        0.285395      0.006519         0.020450        0.005540
# 9        0.175148      0.003182         0.014701        0.001326
# 10       0.171587      0.008067         0.005247        0.006633
# 11       0.263445      0.006404         0.013602        0.003078
# 12       0.300075      0.005741         0.019844        0.003364
# 13       0.249356      0.005938         0.013091        0.003922
# 14       0.263259      0.005719         0.016231        0.007886
# 15       0.221517      0.008426         0.012721        0.003719
# 16       0.168461      0.005194         0.013343        0.002675
# 17       0.235640      0.010366         0.013186        0.003929
# 18       0.280416      0.005763         0.016361        0.001217
# 19       0.267073      0.017479         0.015460        0.001926
# 20       0.262807      0.015878         0.014003        0.003240
# 21       0.265804      0.014199         0.016053        0.000696
# 22       0.154834      0.012824         0.009445        0.006803
# 23       0.273221      0.007624         0.016770        0.003827
# 24       0.313873      0.011592         0.015948        0.001880
# 25       0.224172      0.008160         0.013933        0.006500
# 26       0.303825      0.025238         0.018848        0.002509
# 27       0.219220      0.006192         0.014272        0.002994
# 28       0.310016      0.004942         0.017626        0.004166
# 29       0.482034      0.225569         0.029264        0.014608
# 30       0.446561      0.021510         0.027894        0.005588
# 31       0.849617      0.019991         0.049133        0.002185
# 32       0.748521      0.025058         0.047994        0.001223
# 33       0.493915      0.011483         0.031604        0.004995
# 34       0.826893      0.017428         0.046189        0.002760
# 35       0.559749      0.024624         0.035629        0.005927
# 36       0.665633      0.023542         0.039655        0.004505
# 37       0.811287      0.023224         0.054064        0.007758
# 38       0.563689      0.035256         0.034616        0.003458
# 39       0.433381      0.237878         0.022537        0.015603
# 40       0.267044      0.009197         0.014099        0.002642
# 41       0.283830      0.010484         0.017344        0.003619
# 42       0.283904      0.016828         0.021344        0.012166
# 43       0.188947      0.014055         0.008874        0.005563
# 44       0.304988      0.009246         0.017464        0.003269
# 45       0.167423      0.012187         0.016056        0.001267
# 46       0.309137      0.014117         0.025189        0.007812
# 47       0.170659      0.005835         0.007170        0.006205
# 48       0.308405      0.012269         0.020517        0.006185
# 49       0.238312      0.005310         0.017713        0.002650
#
#    param_min_samples_leaf param_max_depth  \
# 0                      13               9
# 1                      12               8
# 2                       9              12
# 3                      11               2
# 4                      12              12
# 5                       6               5
# 6                      13              15
# 7                      12              15
# 8                       6              14
# 9                      11               4
# 10                     15               3
# 11                     12              11
# 12                      5              11
# 13                     11               8
# 14                     14              14
# 15                      9               6
# 16                      5               3
# 17                      5               6
# 18                      7              10
# 19                     14              11
# 20                     13               8
# 21                     15              13
# 22                      8               2
# 23                     10              13
# 24                      5              12
# 25                      6               6
# 26                     12              14
# 27                      7               5
# 28                      8              14
# 29                      6              15
# 30                     14               2
# 31                      8              11
# 32                     15              15
# 33                     10               3
# 34                      8              15
# 35                      8               4
# 36                     10               6
# 37                     11              10
# 38                     14               4
# 39                     12              13
# 40                      8               9
# 41                     10              12
# 42                     11              14
# 43                      8               3
# 44                      7              13
# 45                      6               3
# 46                      7              15
# 47                     11               3
# 48                      7              14
# 49                     13               7
#
#                                        params  split0_test_score  \
# 0    {'min_samples_leaf': 13, 'max_depth': 9}           0.875000
# 1    {'min_samples_leaf': 12, 'max_depth': 8}           0.876923
# 2    {'min_samples_leaf': 9, 'max_depth': 12}           0.878846
# 3    {'min_samples_leaf': 11, 'max_depth': 2}           0.753846
# 4   {'min_samples_leaf': 12, 'max_depth': 12}           0.870192
# 5     {'min_samples_leaf': 6, 'max_depth': 5}           0.870192
# 6   {'min_samples_leaf': 13, 'max_depth': 15}           0.869231
# 7   {'min_samples_leaf': 12, 'max_depth': 15}           0.875962
# 8    {'min_samples_leaf': 6, 'max_depth': 14}           0.880769
# 9    {'min_samples_leaf': 11, 'max_depth': 4}           0.858654
# 10   {'min_samples_leaf': 15, 'max_depth': 3}           0.830769
# 11  {'min_samples_leaf': 12, 'max_depth': 11}           0.873077
# 12   {'min_samples_leaf': 5, 'max_depth': 11}           0.878846
# 13   {'min_samples_leaf': 11, 'max_depth': 8}           0.875000
# 14  {'min_samples_leaf': 14, 'max_depth': 14}           0.874038
# 15    {'min_samples_leaf': 9, 'max_depth': 6}           0.869231
# 16    {'min_samples_leaf': 5, 'max_depth': 3}           0.827885
# 17    {'min_samples_leaf': 5, 'max_depth': 6}           0.875000
# 18   {'min_samples_leaf': 7, 'max_depth': 10}           0.876923
# 19  {'min_samples_leaf': 14, 'max_depth': 11}           0.872115
# 20   {'min_samples_leaf': 13, 'max_depth': 8}           0.875000
# 21  {'min_samples_leaf': 15, 'max_depth': 13}           0.871154
# 22    {'min_samples_leaf': 8, 'max_depth': 2}           0.753846
# 23  {'min_samples_leaf': 10, 'max_depth': 13}           0.877885
# 24   {'min_samples_leaf': 5, 'max_depth': 12}           0.882692
# 25    {'min_samples_leaf': 6, 'max_depth': 6}           0.874038
# 26  {'min_samples_leaf': 12, 'max_depth': 14}           0.875000
# 27    {'min_samples_leaf': 7, 'max_depth': 5}           0.871154
# 28   {'min_samples_leaf': 8, 'max_depth': 14}           0.878846
# 29   {'min_samples_leaf': 6, 'max_depth': 15}           0.884615
# 30   {'min_samples_leaf': 14, 'max_depth': 2}           0.753846
# 31   {'min_samples_leaf': 8, 'max_depth': 11}           0.877885
# 32  {'min_samples_leaf': 15, 'max_depth': 15}           0.875962
# 33   {'min_samples_leaf': 10, 'max_depth': 3}           0.828846
# 34   {'min_samples_leaf': 8, 'max_depth': 15}           0.879808
# 35    {'min_samples_leaf': 8, 'max_depth': 4}           0.857692
# 36   {'min_samples_leaf': 10, 'max_depth': 6}           0.880769
# 37  {'min_samples_leaf': 11, 'max_depth': 10}           0.872115
# 38   {'min_samples_leaf': 14, 'max_depth': 4}           0.858654
# 39  {'min_samples_leaf': 12, 'max_depth': 13}           0.875000
# 40    {'min_samples_leaf': 8, 'max_depth': 9}           0.877885
# 41  {'min_samples_leaf': 10, 'max_depth': 12}           0.875962
# 42  {'min_samples_leaf': 11, 'max_depth': 14}           0.873077
# 43    {'min_samples_leaf': 8, 'max_depth': 3}           0.827885
# 44   {'min_samples_leaf': 7, 'max_depth': 13}           0.878846
# 45    {'min_samples_leaf': 6, 'max_depth': 3}           0.827885
# 46   {'min_samples_leaf': 7, 'max_depth': 15}           0.877885
# 47   {'min_samples_leaf': 11, 'max_depth': 3}           0.832692
# 48   {'min_samples_leaf': 7, 'max_depth': 14}           0.876923
# 49   {'min_samples_leaf': 13, 'max_depth': 7}           0.875000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.864423           0.868142           0.863330
# 1            0.865385           0.868142           0.861405
# 2            0.873077           0.871030           0.863330
# 3            0.755769           0.754572           0.770934
# 4            0.865385           0.874880           0.859480
# 5            0.851923           0.862368           0.858518
# 6            0.865385           0.870067           0.862368
# 7            0.863462           0.871992           0.860443
# 8            0.877885           0.875842           0.870067
# 9            0.838462           0.846006           0.841193
# 10           0.821154           0.801732           0.824832
# 11           0.863462           0.870067           0.858518
# 12           0.876923           0.884504           0.870067
# 13           0.864423           0.869105           0.858518
# 14           0.865385           0.871030           0.859480
# 15           0.861538           0.863330           0.857555
# 16           0.812500           0.801732           0.823869
# 17           0.856731           0.865255           0.856593
# 18           0.870192           0.881617           0.871030
# 19           0.858654           0.867180           0.861405
# 20           0.866346           0.868142           0.853705
# 21           0.860577           0.865255           0.866218
# 22           0.755769           0.754572           0.770934
# 23           0.862500           0.874880           0.865255
# 24           0.875962           0.878730           0.870067
# 25           0.857692           0.863330           0.855630
# 26           0.865385           0.870067           0.859480
# 27           0.855769           0.864293           0.859480
# 28           0.875000           0.877767           0.862368
# 29           0.878846           0.875842           0.872955
# 30           0.755769           0.754572           0.770934
# 31           0.870192           0.872955           0.869105
# 32           0.861538           0.863330           0.866218
# 33           0.815385           0.801732           0.822907
# 34           0.875000           0.871992           0.863330
# 35           0.836538           0.846006           0.842156
# 36           0.859615           0.865255           0.859480
# 37           0.865385           0.873917           0.857555
# 38           0.841346           0.844081           0.843118
# 39           0.865385           0.870067           0.861405
# 40           0.868269           0.871992           0.862368
# 41           0.868269           0.868142           0.862368
# 42           0.864423           0.872955           0.860443
# 43           0.815385           0.804620           0.822907
# 44           0.874038           0.880654           0.865255
# 45           0.816346           0.801732           0.823869
# 46           0.878846           0.879692           0.868142
# 47           0.815385           0.801732           0.823869
# 48           0.876923           0.875842           0.868142
# 49           0.860577           0.866218           0.856593
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.868142         0.867808        0.004086               26
# 1            0.871030         0.868577        0.005244               20
# 2            0.880654         0.873388        0.006155               11
# 3            0.753609         0.757746        0.006637               48
# 4            0.874880         0.868963        0.005903               16
# 5            0.858518         0.860304        0.005978               38
# 6            0.872955         0.868001        0.003712               23
# 7            0.872955         0.868963        0.005949               18
# 8            0.884504         0.877814        0.004846                4
# 9            0.843118         0.845487        0.007029               40
# 10           0.829644         0.821626        0.010527               42
# 11           0.869105         0.866846        0.005198               29
# 12           0.878730         0.877814        0.004636                3
# 13           0.871992         0.867808        0.005808               26
# 14           0.871030         0.868193        0.005178               22
# 15           0.864293         0.863189        0.003800               36
# 16           0.832531         0.819703        0.011169               46
# 17           0.864293         0.863574        0.006774               34
# 18           0.878730         0.875698        0.004423                8
# 19           0.869105         0.865692        0.004961               32
# 20           0.871030         0.866845        0.007192               31
# 21           0.871030         0.866847        0.003957               28
# 22           0.753609         0.757746        0.006637               48
# 23           0.875842         0.871272        0.006177               13
# 24           0.886429         0.878776        0.005616                2
# 25           0.868142         0.863767        0.006752               33
# 26           0.871992         0.868385        0.005439               21
# 27           0.858518         0.861843        0.005408               37
# 28           0.881617         0.875120        0.006719                9
# 29           0.882579         0.878968        0.004263                1
# 30           0.753609         0.757746        0.006637               48
# 31           0.878730         0.873773        0.003918               10
# 32           0.872955         0.868000        0.005562               24
# 33           0.829644         0.819703        0.010337               47
# 34           0.875842         0.873194        0.005527               12
# 35           0.839269         0.844332        0.007381               41
# 36           0.869105         0.866845        0.007849               30
# 37           0.871030         0.868000        0.005951               24
# 38           0.844081         0.846256        0.006279               39
# 39           0.871992         0.868770        0.004829               19
# 40           0.873917         0.870886        0.005269               14
# 41           0.876805         0.870309        0.005405               15
# 42           0.873917         0.868963        0.005488               17
# 43           0.830606         0.820280        0.009387               44
# 44           0.883542         0.876467        0.006401                6
# 45           0.830606         0.820088        0.010360               45
# 46           0.883542         0.877621        0.005114                5
# 47           0.829644         0.820664        0.011152               43
# 48           0.881617         0.875890        0.004358                7
# 49           0.859480         0.863574        0.006512               35
